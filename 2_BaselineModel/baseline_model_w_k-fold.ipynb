# %% [markdown]
# # Baseline Model with k-fold Cross Validation
#
# ## Table of Contents
# 1. [Model Choice](#model-choice)
# 2. [Feature Selection](#feature-selection)
# 3. [Implementation](#implementation)
# 4. [Evaluation](#evaluation)

# %%
# Import necessary libraries

import random

import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import StratifiedGroupKFold
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from datasets import concatenate_datasets, load_dataset

# %%
if torch.cuda.is_available():
    DEVICE = torch.device("cuda")  # NVIDIA GPU
elif torch.backends.mps.is_available():
    DEVICE = torch.device("mps")   # Apple Silicon (M1/M2/M3)
else:
    DEVICE = torch.device("cpu")   # Fallback

print(f"Using Device: {DEVICE}")
# Out:
# Using Device: mps

# %% [markdown]
# ## Model Choice
#
# [Explain why you've chosen a particular model as the baseline. This could be a simple statistical model or a basic machine learning model. Justify your choice.]

# %% [markdown]
# We chose a convolutional neural network (CNN) as the baseline model for our aesthetic emotions map project. CNNs are well-suited for image classification tasks due to their ability to capture spatial hierarchies in images. They can learn to recognize patterns and features in the images that are relevant for predicting the associated emotions. Additionally, CNNs have been widely used and have shown strong performance in various image-related tasks, making them a reasonable starting point for our project.

# %% [markdown]
# ## Feature Selection
#
# [Indicate which features from the dataset you will be using for the baseline model, and justify your selection.]
#
# For the baseline model, we will be using the raw pixel values of the images as features. This is a common approach for image classification tasks, as it allows the model to learn directly from the visual data without any manual feature engineering. By using the raw pixel values, we can leverage the CNN's ability to automatically extract relevant features from the images during training.

# %%
# Loading the dataset using Hugging Face's datasets library
dataset = load_dataset("bjoern-doege/aesthetic-emotions-map")
# Out:
# Resolving data files:   0%|          | 0/4721 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/1025 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/1089 [00:00<?, ?it/s]

# %%
NORMALIZE_MEAN=[0.5111283659934998, 0.48830345273017883, 0.46479079127311707]
NORMALIZE_STD=[0.3433663249015808, 0.3207928538322449, 0.32255250215530396]

# %%
BASE_TRANSFORM = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(NORMALIZE_MEAN, NORMALIZE_STD),
])

# %%
# Converting labels to ids
# PyTorch's ImageFolder would do this automatically, but we are using Hugging Face's datasets library
label_names = sorted(dataset["train"].unique("label"))
label_to_id = {label: i for i, label in enumerate(label_names)}

# %%
# This function will be applied to each example in the dataset to preprocess the images and labels
# Again, this is necessary because we are using Hugging Face's datasets library instead of PyTorch's ImageFolder
def preprocess(examples):
    return {
        "image": [
            BASE_TRANSFORM(image.convert("RGB"))
            for image in examples["image"]
        ],
        "label": torch.tensor(
            [label_to_id[label] for label in examples["label"]],
            dtype=torch.long,
        ),
    }

# %%
# Use train + validation for cross-validation and keep test untouched for final evaluation.
trainval_dataset = concatenate_datasets([
    dataset["train"],
    dataset["validation"],
])

test_dataset = dataset["test"]

BATCH_SIZE = 64
LEARNING_RATE = 0.001
NUM_EPOCHS = 10
N_SPLITS = 5
RANDOM_STATE = 42


def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True


seed_everything(RANDOM_STATE)

# %%
X = np.arange(len(trainval_dataset))
y = [label_to_id[label] for label in trainval_dataset["label"]]
groups = trainval_dataset["style"]

cv = StratifiedGroupKFold(
    n_splits=N_SPLITS,
    shuffle=True,
    random_state=RANDOM_STATE,
)

style_overlap = set(trainval_dataset["style"]) & set(test_dataset["style"])
print(f"Train+validation samples: {len(trainval_dataset)}")
print(f"Test samples: {len(test_dataset)}")
print(f"Overlapping styles between train+validation and test: {len(style_overlap)}")
# Out:
# Train+validation samples: 5744
# Test samples: 1088
# Overlapping styles between train+validation and test: 0

# %% [markdown]
# ## Implementation
#
# [Implement your baseline model here.]
#
# The baseline CNN architecture consists of the following layers assuming an input image size of 224x224 pixels:
# 1. **Convolutional Layer 1**: 32 filters, kernel size of 3x3, ReLU activation
# 2. **Max Pooling Layer 1**: Pool size of 2x2
# 3. **Convolutional Layer 2**: 64 filters, kernel size of 3x3, ReLU activation
# 4. **Max Pooling Layer 2**: Pool size of 2x2
# 5. **Convolutional Layer 3**: 128 filters, kernel size of 3x3, ReLU activation
# 6. **Max Pooling Layer 3**: Pool size of 2x2
# 7. **Flatten Layer**: Flattens the output from the previous layer
# 8. **Fully Connected Layer 1**: 256 neurons, ReLU activation
# 9. **Dropout Layer**: Dropout rate of 0.5 to reduce overfitting
# 10. **Output Layer**: Number of neurons equal to the number of emotion classes

# %%
# Initialize and train the baseline model
class BaselineCNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(
                in_channels=3,
                out_channels=32,
                kernel_size=3,
                padding=1,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            # Block 2
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                padding=1,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            # Block 3
            nn.Conv2d(
                in_channels=64,
                out_channels=128,
                kernel_size=3,
                padding=1,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            # For 224x224 input images: 224 -> 112 -> 56 -> 28
            nn.Linear(128 * 28 * 28, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
def create_model():
    return BaselineCNN(num_classes=len(label_names)).to(DEVICE)


def create_optimizer(model):
    return optim.Adam(model.parameters(), lr=LEARNING_RATE)


def create_loss_fn():
    return nn.CrossEntropyLoss()


def create_dataloader(ds, batch_size=BATCH_SIZE, shuffle=False, seed=RANDOM_STATE):
    generator = None
    if shuffle:
        generator = torch.Generator()
        generator.manual_seed(seed)

    return DataLoader(
        ds.with_transform(preprocess),
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=0,
        generator=generator,
    )

# %%
def train_one_epoch(model, train_loader, optimizer, loss_fn, device):
    model.train()

    running_loss = 0.0
    y_true = []
    y_pred = []

    for batch in train_loader:
        images = batch["image"].to(device)
        labels = batch["label"].to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        predicted = outputs.argmax(dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

    return compute_metrics(y_true, y_pred, running_loss)


def evaluate(model, data_loader, loss_fn, device):
    model.eval()

    running_loss = 0.0
    y_true = []
    y_pred = []

    with torch.no_grad():
        for batch in data_loader:
            images = batch["image"].to(device)
            labels = batch["label"].to(device)

            outputs = model(images)
            loss = loss_fn(outputs, labels)

            running_loss += loss.item() * images.size(0)
            predicted = outputs.argmax(dim=1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    return compute_metrics(y_true, y_pred, running_loss)


def compute_metrics(y_true, y_pred, total_loss):
    return {
        "loss": total_loss / len(y_true),
        "accuracy": accuracy_score(y_true, y_pred),
        "precision_weighted": precision_score(y_true, y_pred, average="weighted", zero_division=0),
        "recall_weighted": recall_score(y_true, y_pred, average="weighted", zero_division=0),
        "f1_weighted": f1_score(y_true, y_pred, average="weighted", zero_division=0),
        "f1_macro": f1_score(y_true, y_pred, average="macro", zero_division=0),
        "y_true": y_true,
        "y_pred": y_pred,
    }

# %%
fold_metrics = []

for fold, (train_idx, val_idx) in enumerate(cv.split(X, y, groups), start=1):
    print(f"\nFold {fold}/{N_SPLITS}")
    fold_seed = RANDOM_STATE + fold
    seed_everything(fold_seed)

    fold_train_dataset = trainval_dataset.select(train_idx.tolist())
    fold_val_dataset = trainval_dataset.select(val_idx.tolist())

    train_loader = create_dataloader(fold_train_dataset, shuffle=True, seed=fold_seed)
    val_loader = create_dataloader(fold_val_dataset, shuffle=False)

    model = create_model()
    optimizer = create_optimizer(model)
    loss_fn = create_loss_fn()

    for epoch in range(NUM_EPOCHS):
        train_metrics = train_one_epoch(model, train_loader, optimizer, loss_fn, DEVICE)
        val_metrics = evaluate(model, val_loader, loss_fn, DEVICE)

        print(
            f"Epoch {epoch + 1}/{NUM_EPOCHS} | "
            f"train_loss={train_metrics['loss']:.4f}, "
            f"train_acc={train_metrics['accuracy']:.4f}, "
            f"train_macro_f1={train_metrics['f1_macro']:.4f} | "
            f"val_loss={val_metrics['loss']:.4f}, "
            f"val_acc={val_metrics['accuracy']:.4f}, "
            f"val_macro_f1={val_metrics['f1_macro']:.4f}"
        )

    fold_metrics.append({
        "fold": fold,
        "val_loss": val_metrics["loss"],
        "val_accuracy": val_metrics["accuracy"],
        "val_f1_weighted": val_metrics["f1_weighted"],
        "val_f1_macro": val_metrics["f1_macro"],
    })

val_macro_f1_scores = [metrics["val_f1_macro"] for metrics in fold_metrics]
val_accuracy_scores = [metrics["val_accuracy"] for metrics in fold_metrics]

print("\nCross-validation summary")
print(f"Accuracy: {np.mean(val_accuracy_scores):.4f} +/- {np.std(val_accuracy_scores):.4f}")
print(f"Macro F1: {np.mean(val_macro_f1_scores):.4f} +/- {np.std(val_macro_f1_scores):.4f}")
# Out:
# Fold 1/5
# Epoch 1/10 | train_loss=1.8626, train_acc=0.3095, train_macro_f1=0.2224 | val_loss=1.7866, val_acc=0.3498, val_macro_f1=0.2147
# Epoch 2/10 | train_loss=1.5637, train_acc=0.3913, train_macro_f1=0.3474 | val_loss=1.9760, val_acc=0.3550, val_macro_f1=0.2655
# Epoch 3/10 | train_loss=1.4015, train_acc=0.4599, train_macro_f1=0.4235 | val_loss=2.1897, val_acc=0.3602, val_macro_f1=0.2426
# Epoch 4/10 | train_loss=1.2600, train_acc=0.5159, train_macro_f1=0.4863 | val_loss=2.3495, val_acc=0.3568, val_macro_f1=0.2645
# Epoch 5/10 | train_loss=1.1022, train_acc=0.5825, train_macro_f1=0.5653 | val_loss=2.2337, val_acc=0.4010, val_macro_f1=0.3032
# Epoch 6/10 | train_loss=0.9074, train_acc=0.6712, train_macro_f1=0.6620 | val_loss=2.5408, val_acc=0.3663, val_macro_f1=0.2992
# Epoch 7/10 | train_loss=0.7394, train_acc=0.7274, train_macro_f1=0.7252 | val_loss=2.7596, val_acc=0.3628, val_macro_f1=0.2932
# Epoch 8/10 | train_loss=0.5605, train_acc=0.7979, train_macro_f1=0.7943 | val_loss=2.8598, val_acc=0.3811, val_macro_f1=0.2999
# Epoch 9/10 | train_loss=0.4253, train_acc=0.8510, train_macro_f1=0.8516 | val_loss=3.3791, val_acc=0.3724, val_macro_f1=0.3322
# Epoch 10/10 | train_loss=0.3788, train_acc=0.8696, train_macro_f1=0.8709 | val_loss=3.4835, val_acc=0.3845, val_macro_f1=0.3234
#
# Fold 2/5
# Epoch 1/10 | train_loss=1.8580, train_acc=0.3149, train_macro_f1=0.2155 | val_loss=1.8428, val_acc=0.2977, val_macro_f1=0.1904
# Epoch 2/10 | train_loss=1.5086, train_acc=0.4284, train_macro_f1=0.3652 | val_loss=1.8992, val_acc=0.3047, val_macro_f1=0.2441
# Epoch 3/10 | train_loss=1.3569, train_acc=0.4800, train_macro_f1=0.4329 | val_loss=2.0052, val_acc=0.3212, val_macro_f1=0.2918
# Epoch 4/10 | train_loss=1.2216, train_acc=0.5449, train_macro_f1=0.5079 | val_loss=1.9329, val_acc=0.3168, val_macro_f1=0.2591
# Epoch 5/10 | train_loss=1.0508, train_acc=0.6119, train_macro_f1=0.5835 | val_loss=2.1277, val_acc=0.3151, val_macro_f1=0.2834
# Epoch 6/10 | train_loss=0.8566, train_acc=0.6908, train_macro_f1=0.6655 | val_loss=2.3199, val_acc=0.3203, val_macro_f1=0.2818
# Epoch 7/10 | train_loss=0.6588, train_acc=0.7596, train_macro_f1=0.7453 | val_loss=2.6077, val_acc=0.3333, val_macro_f1=0.2665
# Epoch 8/10 | train_loss=0.5146, train_acc=0.8199, train_macro_f1=0.8098 | val_loss=2.9802, val_acc=0.3316, val_macro_f1=0.2721
# Epoch 9/10 | train_loss=0.3505, train_acc=0.8798, train_macro_f1=0.8719 | val_loss=3.5553, val_acc=0.3047, val_macro_f1=0.2433
# Epoch 10/10 | train_loss=0.2794, train_acc=0.9092, train_macro_f1=0.9039 | val_loss=4.1969, val_acc=0.2891, val_macro_f1=0.2384
#
# Fold 3/5
# Epoch 1/10 | train_loss=1.8817, train_acc=0.2942, train_macro_f1=0.1916 | val_loss=1.7371, val_acc=0.3177, val_macro_f1=0.2471
# Epoch 2/10 | train_loss=1.5774, train_acc=0.3883, train_macro_f1=0.3210 | val_loss=1.7080, val_acc=0.3490, val_macro_f1=0.2815
# Epoch 3/10 | train_loss=1.4457, train_acc=0.4434, train_macro_f1=0.3961 | val_loss=1.7805, val_acc=0.3160, val_macro_f1=0.2718
# Epoch 4/10 | train_loss=1.3350, train_acc=0.4889, train_macro_f1=0.4495 | val_loss=1.8286, val_acc=0.3247, val_macro_f1=0.2613
# Epoch 5/10 | train_loss=1.1994, train_acc=0.5409, train_macro_f1=0.5121 | val_loss=1.8316, val_acc=0.3377, val_macro_f1=0.2596
# Epoch 6/10 | train_loss=1.0647, train_acc=0.5930, train_macro_f1=0.5685 | val_loss=2.1240, val_acc=0.3455, val_macro_f1=0.3003
# Epoch 7/10 | train_loss=0.9048, train_acc=0.6574, train_macro_f1=0.6410 | val_loss=2.3792, val_acc=0.3325, val_macro_f1=0.2857
# Epoch 8/10 | train_loss=0.8021, train_acc=0.6997, train_macro_f1=0.6860 | val_loss=2.3269, val_acc=0.3628, val_macro_f1=0.2991
# Epoch 9/10 | train_loss=0.6821, train_acc=0.7533, train_macro_f1=0.7433 | val_loss=2.7173, val_acc=0.3411, val_macro_f1=0.2829
# Epoch 10/10 | train_loss=0.5668, train_acc=0.7968, train_macro_f1=0.7891 | val_loss=2.5901, val_acc=0.3403, val_macro_f1=0.3091
#
# Fold 4/5
# Epoch 1/10 | train_loss=1.8475, train_acc=0.3155, train_macro_f1=0.2232 | val_loss=1.6472, val_acc=0.3837, val_macro_f1=0.2833
# Epoch 2/10 | train_loss=1.5732, train_acc=0.3844, train_macro_f1=0.3129 | val_loss=1.6005, val_acc=0.4089, val_macro_f1=0.3238
# Epoch 3/10 | train_loss=1.4215, train_acc=0.4551, train_macro_f1=0.4079 | val_loss=1.5134, val_acc=0.4089, val_macro_f1=0.3652
# Epoch 4/10 | train_loss=1.2579, train_acc=0.5185, train_macro_f1=0.4847 | val_loss=1.6488, val_acc=0.3898, val_macro_f1=0.3471
# Epoch 5/10 | train_loss=1.1301, train_acc=0.5686, train_macro_f1=0.5464 | val_loss=1.6267, val_acc=0.3958, val_macro_f1=0.3364
# Epoch 6/10 | train_loss=0.9230, train_acc=0.6540, train_macro_f1=0.6398 | val_loss=1.7229, val_acc=0.4184, val_macro_f1=0.3627
# Epoch 7/10 | train_loss=0.7560, train_acc=0.7184, train_macro_f1=0.7079 | val_loss=1.8924, val_acc=0.4175, val_macro_f1=0.3777
# Epoch 8/10 | train_loss=0.6342, train_acc=0.7726, train_macro_f1=0.7681 | val_loss=2.0622, val_acc=0.4175, val_macro_f1=0.3418
# Epoch 9/10 | train_loss=0.4917, train_acc=0.8199, train_macro_f1=0.8150 | val_loss=2.4170, val_acc=0.3811, val_macro_f1=0.3579
# Epoch 10/10 | train_loss=0.4207, train_acc=0.8528, train_macro_f1=0.8491 | val_loss=2.5258, val_acc=0.4080, val_macro_f1=0.3628
#
# Fold 5/5
# Epoch 1/10 | train_loss=1.8197, train_acc=0.3251, train_macro_f1=0.2395 | val_loss=1.7070, val_acc=0.2905, val_macro_f1=0.1930
# Epoch 2/10 | train_loss=1.5445, train_acc=0.4078, train_macro_f1=0.3497 | val_loss=1.6645, val_acc=0.3468, val_macro_f1=0.3095
# Epoch 3/10 | train_loss=1.3951, train_acc=0.4625, train_macro_f1=0.4228 | val_loss=1.6960, val_acc=0.3724, val_macro_f1=0.3397
# Epoch 4/10 | train_loss=1.2742, train_acc=0.5139, train_macro_f1=0.4814 | val_loss=1.6309, val_acc=0.3706, val_macro_f1=0.3273
# Epoch 5/10 | train_loss=1.1222, train_acc=0.5736, train_macro_f1=0.5491 | val_loss=1.7331, val_acc=0.3530, val_macro_f1=0.3101
# Epoch 6/10 | train_loss=0.9747, train_acc=0.6365, train_macro_f1=0.6194 | val_loss=1.9124, val_acc=0.3706, val_macro_f1=0.3322
# Epoch 7/10 | train_loss=0.8242, train_acc=0.7010, train_macro_f1=0.6911 | val_loss=2.1352, val_acc=0.3310, val_macro_f1=0.2876
# Epoch 8/10 | train_loss=0.6671, train_acc=0.7602, train_macro_f1=0.7479 | val_loss=2.3997, val_acc=0.3539, val_macro_f1=0.2914
# Epoch 9/10 | train_loss=0.5279, train_acc=0.8082, train_macro_f1=0.8029 | val_loss=2.6366, val_acc=0.3442, val_macro_f1=0.2989
# Epoch 10/10 | train_loss=0.4018, train_acc=0.8598, train_macro_f1=0.8564 | val_loss=2.9823, val_acc=0.3213, val_macro_f1=0.2890
#
# Cross-validation summary
# Accuracy: 0.3486 +/- 0.0428
# Macro F1: 0.3045 +/- 0.0410

# %% [markdown]
# ## Evaluation
#
# [Clearly state what metrics you will use to evaluate the model's performance. These metrics will serve as a starting point for evaluating more complex models later on.]
#
# We are using the following metrics to evaluate the performance of our baseline model:
# 1. **Accuracy**: The proportion of correctly classified instances among the total instances.
# 2. **Precision**: The proportion of true positive predictions among all positive predictions.
# 3. **Recall**: The proportion of true positive predictions among all actual positives.
# 4. **F1 Score**: The harmonic mean of precision and recall, providing a balance between the two metrics.
# 5. **Confusion Matrix**: A table that describes the performance of the classification model by showing the true positives, true negatives, false positives, and false negatives for each class.
# 6. **Classification Report**: A comprehensive report that includes precision, recall, F1 score, and support for each class, providing a detailed overview of the model's performance across all classes.

# %%
# Train one final model on all train+validation data, then evaluate once on the untouched test set.
final_seed = RANDOM_STATE + N_SPLITS + 1
seed_everything(final_seed)
final_model = create_model()
final_optimizer = create_optimizer(final_model)
final_loss_fn = create_loss_fn()

trainval_loader = create_dataloader(trainval_dataset, shuffle=True, seed=final_seed)
test_loader = create_dataloader(test_dataset, shuffle=False)

for epoch in range(NUM_EPOCHS):
    train_metrics = train_one_epoch(final_model, trainval_loader, final_optimizer, final_loss_fn, DEVICE)
    print(
        f"Final model epoch {epoch + 1}/{NUM_EPOCHS} | "
        f"train_loss={train_metrics['loss']:.4f}, "
        f"train_acc={train_metrics['accuracy']:.4f}, "
        f"train_macro_f1={train_metrics['f1_macro']:.4f}"
    )

test_metrics = evaluate(final_model, test_loader, final_loss_fn, DEVICE)

print("\nFinal test metrics")
print(f"Test loss: {test_metrics['loss']:.4f}")
print(f"Accuracy: {test_metrics['accuracy']:.4f}")
print(f"Weighted precision: {test_metrics['precision_weighted']:.4f}")
print(f"Weighted recall: {test_metrics['recall_weighted']:.4f}")
print(f"Weighted F1: {test_metrics['f1_weighted']:.4f}")
print(f"Macro F1: {test_metrics['f1_macro']:.4f}")

print("\nClassification report:")
print(classification_report(
    test_metrics["y_true"],
    test_metrics["y_pred"],
    labels=list(range(len(label_names))),
    target_names=label_names,
    zero_division=0,
))

print("\nConfusion matrix:")
print(confusion_matrix(test_metrics["y_true"], test_metrics["y_pred"]))
# Out:
# Final model epoch 1/10 | train_loss=1.9223, train_acc=0.2996, train_macro_f1=0.1910
# Final model epoch 2/10 | train_loss=1.6084, train_acc=0.3975, train_macro_f1=0.3271
# Final model epoch 3/10 | train_loss=1.4767, train_acc=0.4352, train_macro_f1=0.3692
# Final model epoch 4/10 | train_loss=1.3332, train_acc=0.4932, train_macro_f1=0.4515
# Final model epoch 5/10 | train_loss=1.2081, train_acc=0.5420, train_macro_f1=0.5078
# Final model epoch 6/10 | train_loss=1.0641, train_acc=0.6057, train_macro_f1=0.5810
# Final model epoch 7/10 | train_loss=0.8925, train_acc=0.6664, train_macro_f1=0.6492
# Final model epoch 8/10 | train_loss=0.7342, train_acc=0.7267, train_macro_f1=0.7190
# Final model epoch 9/10 | train_loss=0.5909, train_acc=0.7843, train_macro_f1=0.7778
# Final model epoch 10/10 | train_loss=0.4542, train_acc=0.8424, train_macro_f1=0.8383
#
# Final test metrics
# Test loss: 2.5862
# Accuracy: 0.4237
# Weighted precision: 0.4168
# Weighted recall: 0.4237
# Weighted F1: 0.4050
# Macro F1: 0.3659
#
# Classification report:
#                        precision    recall  f1-score   support
#
#   aesthetic_emptiness       0.40      0.24      0.30        80
# energetic_playfulness       0.22      0.14      0.17        64
#   intellectual_unease       0.44      0.67      0.53       240
#    lighthearted_humor       0.59      0.48      0.53       144
#           melancholic       0.47      0.39      0.42        96
#             pure_calm       0.48      0.28      0.35       128
#         serene_beauty       0.21      0.12      0.16       128
#    sublime_activation       0.39      0.55      0.46       208
#
#              accuracy                           0.42      1088
#             macro avg       0.40      0.36      0.37      1088
#          weighted avg       0.42      0.42      0.40      1088
#
#
# Confusion matrix:
# [[ 19   0  26   5   7  11   1  11]
#  [  1   9  13  11   0   4   4  22]
#  [  2   1 160   0  11   1  13  52]
#  [  7  23  17  69   0   3   3  22]
#  [  5   0  36   2  37   6   6   4]
#  [  8   1  30  18  14  36  17   4]
#  [  0   1  30   3   7   7  16  64]
#  [  5   6  49   8   3   7  15 115]]

# %%
torch.save(final_model.state_dict(), "model_w_k-fold.pth")
